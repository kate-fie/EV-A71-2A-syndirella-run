# %%
import pandas as pd
import os
os.chdir('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/posebusters_79')

# %%
df = pd.read_csv('posebusters_results.csv')
df
# Out:
#                     file                                  molecule  \
# 0    bases_c79_named.sdf    Cn1ncc(NC(=O)CC#N)c1NC(=O)[C@@H]1CCCO1
# 1    bases_c79_named.sdf     Cn1ncc(NC(=O)CC#N)c1NC(=O)[C@H]1CCCO1
# 2    bases_c79_named.sdf    N#CCC(=O)Nc1cccc(NC(=O)[C@@H]2CCCO2)c1
# 3    bases_c79_named.sdf     N#CCC(=O)Nc1cccc(NC(=O)[C@H]2CCCO2)c1
# 4    bases_c79_named.sdf   Cc1ccc(NC(=O)CC#N)cc1NC(=O)[C@@H]1CCCO1
# ..                   ...                                       ...
# 108  bases_c79_named.sdf  CN(C)C(=O)COc1cncc(NC(=O)[C@@H]2CCCO2)c1
# 109  bases_c79_named.sdf   CN(C)C(=O)COc1cncc(NC(=O)[C@H]2CCCO2)c1
# 110  bases_c79_named.sdf                N#CCC(=O)Nc1ccccc1NC(=O)CO
# 111  bases_c79_named.sdf                N#CCC(=O)Nc1ccncc1NC(=O)CO
# 112  bases_c79_named.sdf             N#CCC(=O)Nc1cc(F)ccc1NC(=O)CO
#
#      mol_pred_loaded  mol_cond_loaded  sanitization  all_atoms_connected  \
# 0               True             True          True                 True
# ...

# %%
df['minimum_distance_to_protein'].value_counts()
# Out:
# minimum_distance_to_protein
# False    113
# Name: count, dtype: int64

# %%
df['volume_overlap_with_protein'].value_counts()
# Out:
# volume_overlap_with_protein
# False    104
# True       9
# Name: count, dtype: int64
