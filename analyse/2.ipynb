# %%
import pandas as pd
import rdkit 
from rdkit import Chem

# %%
df = pd.read_pickle('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/analyse/BHKVBKDDVLQZCR-UHFFFAOYSA-N_cmmskw_to_hippo.pkl.gz')
df
# Out:
#                     base_compound_smiles 1_reaction     1_r1_smiles  \
# 0      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation   O=C(O)C1CCCO1
# 1      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation   O=C(O)C1CCCO1
# 2      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation   O=C(O)C1CCCO1
# 3      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation   O=C(O)C1CCCO1
# 4      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation   O=C(O)C1CCCO1
# ...                                  ...        ...             ...
# 12908  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1OCCC1F
# 12909  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1OCCC1F
# 12910  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1OCCC1F
# 12911  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1OCCC1F
# 12912  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1OCCC1F
#
#                          1_r2_smiles 1_r_previous_product  \
# 0         CC(C)(C)OC(=O)Nc1cccc(N)c1                 None
# ...

# %%
df1 = pd.read_pickle('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/analyse/BHKVBKDDVLQZCR-UHFFFAOYSA-N_hkMgPY_to_hippo.pkl.gz')
df1
# Out:
#                     base_compound_smiles 1_reaction       1_r1_smiles  \
# 0      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 1      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 2      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 3      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 4      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# ...                                  ...        ...               ...
# 12352  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  CC1COC(C(=O)O)C1
# 12353  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  CC1COC(C(=O)O)C1
# 12354  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 12355  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 12356  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
#
#                          1_r2_smiles 1_r_previous_product  \
# 0         CC(C)(C)OC(=O)Nc1cccc(N)c1                 None
# ...

# %%
/data/xchem-fragalysis/kfieseler/A71EV2A_run3/batch0/BHKVBKDDVLQZCR-UHFFFAOYSA-N/output/BHKVBKDDVLQZCR-UHFFFAOYSA-N-cmmskw-2432-C/BHKVBKDDVLQZCR-UHFFFAOYSA-N-cmmskw-2432-C.minimised.mol

Cc1c(NC(=O)[C@@H]2C[C@@H](C)CO2)cccc1NC(=O)C1(C#N)CC(F)C1

# %%
# load .mol file
mol = Chem.MolFromMolFile('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/analyse/BHKVBKDDVLQZCR-UHFFFAOYSA-N-cmmskw-2432-C.minimised.mol')
mol

# %%
smiles = Chem.MolToSmiles(mol)
smiles
# Out:
# 'Cc1c(NC(=O)[C@@H]2C[C@@H](C)CO2)cccc1NC(=O)[C@]1(C#N)C[C@@H](F)C1'

# %%
mol1 = Chem.MolFromSmiles('Cc1c(NC(=O)[C@@H]2C[C@@H](C)CO2)cccc1NC(=O)C1(C#N)CC(F)C1')
mol1

# %%
inchi_key1 = Chem.MolToInchiKey(mol1)
inchi_key1
# Out:
# 'DXOLVTOBDSKNRT-IWLJCYJBSA-N'

# %%
inchi_key = Chem.MolToInchiKey(mol)
inchi_key
# Out:
# 'DXOLVTOBDSKNRT-HXFILWEYSA-N'

# %%
# get number of unique smiles
df = pd.read_pickle('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/base_compounds/syndirella_input_MASTER_run3.pkl')
df
# Out:
#                                  smiles  \
# 0     Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1
# 1     N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1
# 2    Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1
# 3     N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1
# 4    Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N
# ..                                  ...
# 135        N#CCC(=O)Nc1ccncc1(NC(=O)CO)
# 136       Cc1cccc(NC(=O)CO)c1NC(=O)CC#N
# 137       N#CCC(=O)Nc1c(NC(=O)CO)cccc1F
# 138     c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1F
# 139     c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1F
#
#                                              reactants  \
# 0    [('Cn1ncc(NC(=O)OC(C)(C)C)c1N', 'O=C(O)C1CCCO1...
# 1    [('CC(C)(C)OC(=O)Nc1cccc(N)c1', 'O=C(O)C1CCCO1...
# 2    [('CC(C)(C)OC(=O)Nc1cc(N)c(C)cc1', 'O=C(O)C1CC...
# 3    [('Nc1cc(NC(=O)OC(C)(C)C)ccn1', 'O=C(O)C1CCCO1...
# 4    [('CC(C)(C)OC(=O)Nc1cc(N)ccc1C', 'O=C(O)C1CCCO...
# ..                                                 ...
# 135  [('CC(C)(C)OC(=O)Nc1ccncc1(N)', 'O=C(O)CO'), '...
# ...

# %%
# how many unqiue rows includinga all columns
df.drop_duplicates()
len(df)
# Out:
# 140
