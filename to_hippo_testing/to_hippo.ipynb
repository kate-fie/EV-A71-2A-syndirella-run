# %%
import pandas as pd

# %%
df = pd.read_pickle('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/to_hippo_testing/CEQDLNCRDRYDKS-UHFFFAOYSA-N_3aoZ2a_to_hippo.pkl.gz')
df
# Out:
#                     base_compound_smiles 1_reaction     1_r1_smiles  \
# 0     Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation   O=C(O)C1CCCO1
# 1     Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation   O=C(O)C1CCCO1
# 2     Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation   O=C(O)C1CCCO1
# 3     Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation   O=C(O)C1CCCO1
# 4     Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation   O=C(O)C1CCCO1
# ...                                  ...        ...             ...
# 9995  Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation  O=C(O)C1OCCC1F
# 9996  Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation  O=C(O)C1OCCC1F
# 9997  Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation  O=C(O)C1OCCC1F
# 9998  Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation  O=C(O)C1OCCC1F
# 9999  Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  Amidation  O=C(O)C1OCCC1F
#
#                           1_r2_smiles 1_r_previous_product  \
# 0         Cc1ccc(NC(=O)OC(C)(C)C)cc1N                 None
# ...

# %%
df['3_num_atom_diff'].value_counts(dropna=True)
# Out:
# 3_num_atom_diff
# 6    4530
# 5    2964
# 4    1398
# 3     534
# 7     387
# 2     158
# 1      27
# 0       2
# Name: count, dtype: int64

# %%
df = pd.read_csv("/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/batches_run3/batch7.csv")
df
# Out:
#    Unnamed: 0                                    smiles  \
# 0          70     Cc1ccc(OC2CCN(C)C2=O)cc1NC(=O)C1CCCO1
# 1          71   CN1CCC(Oc2ccc(F)c(NC(=O)C3CCCO3)c2)C1=O
# 2          72     Cc1ccc(NC(=O)C2CCCO2)cc1OC1CCN(C)C1=O
# 3          73  Cc1cc(C)c(OC2CCN(C)C2=O)cc1NC(=O)C1CCCO1
# 4          74      CN1CCC(Oc2cncc(NC(=O)C3CCCO3)c2)C1=O
# 5          75      CN1CCC(Oc2cc(NC(=O)C3CCCO3)ccn2)C1=O
# 6          76        Cc1cnc(NC(=O)COC2CCN(C)C2=O)c(O)c1
# 7          77             CN1CCC(OCC(=O)Nc2ccccc2O)C1=O
# 8          78        Cc1ccc(NC(=O)COC2CCN(C)C2=O)c(O)c1
# 9          79          CN1CCC(OCC(=O)Nc2ccc(F)cc2O)C1=O
#
#                                            reactants  \
# 0  [('Cc1ccc(O)cc1N', 'O=C(O)C1CCCO1'), ('Cc1ccc(...
# 1  [('Fc1ccc(O)cc1N', 'O=C(O)C1CCCO1'), ('O=C(Nc1...
# 2  [('Nc1cc(O)c(C)cc1', 'O=C(O)C1CCCO1'), ('Cc1cc...
# 3  [('Nc1cc(O)c(C)cc1C', 'O=C(O)C1CCCO1'), ('Cc1c...
# 4  [('Nc1cncc(O)c1', 'O=C(O)C1CCCO1'), ('O=C(Nc1c...
# ...

# %%
df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/batches_run3/batch8.csv')
df
# Out:
#    Unnamed: 0                                 smiles  \
# 0          80       Cc1cccc(OC2CCN(C)C2=O)c1NC(=O)CO
# 1          81  Cc1cc(C)c(NC(=O)COC2CCN(C)C2=O)c(O)c1
# 2          82       Cc1nccc(OC2CCN(C)C2=O)c1NC(=O)CO
# 3          83  Cc1cc(OC2CCN(C)C2=O)c(NC(=O)CO)c(C)n1
# 4          84     Cc1cnc(NC(=O)CS)c(OC2CCN(C)C2=O)c1
# 5          85          CN1CCC(Oc2ccccc2NC(=O)CS)C1=O
# 6          86     Cc1ccc(NC(=O)CS)c(OC2CCN(C)C2=O)c1
# 7          87       CN1CCC(Oc2cc(F)ccc2NC(=O)CS)C1=O
# 8          88       Cc1cccc(OC2CCN(C)C2=O)c1NC(=O)CS
# 9          89  Cc1cc(C)c(NC(=O)CS)c(OC2CCN(C)C2=O)c1
#
#                                            reactants  \
# 0  [('Cc1cccc(O)c1N', 'C(O)(=O)CO[Si](C(C)(C)C)(C...
# 1  [('Cc1cc(O)c(N)c(C)c1', 'C(O)(=O)CO[Si](C(C)(C...
# 2  [('Oc1ccnc(C)c1N', 'C(O)(=O)CO[Si](C(C)(C)C)(C...
# 3  [('Cc1cc(O)c(N)c(C)n1', 'C(O)(=O)CO[Si](C(C)(C...
# 4  [('Cc1cnc(N)c(O)c1', 'O=C(O)CS'), ('Cc1cnc(NC(...
# 5  [('Nc1ccccc1O', 'O=C(O)CS'), ('O=C(CS)Nc1ccccc...
# ...

# %%
df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/batches_run3/batch3.csv')
df
# Out:
#    Unnamed: 0                                         smiles  \
# 0          30                CN(C)C(=O)c1ccccc1OC1CCN(C)C1=O
# 1          31           CN1CCC(Oc2ccccc2OCC(=O)N2CCOCC2)C1=O
# 2          32        Cc1cccc(OC2CCN(C)C2=O)c1OCC(=O)N1CCOCC1
# 3          33   Cc1cc(C)c(OCC(=O)N2CCOCC2)c(OC2CCN(C)C2=O)c1
# 4          34      Cc1ccc(OC2CCN(C)C2=O)c(OCC(=O)N2CCOCC2)c1
# 5          35      Cc1cnc(OCC(=O)N2CCOCC2)c(OC2CCN(C)C2=O)c1
# 6          36           CC(=O)Nc1cccc(NC(C)=O)c1CNS(C)(=O)=O
# 7          37  CC(=O)Nc1c(CNS(C)(=O)=O)ccc(OCC(=O)N(C)C)c1Br
# 8          38      CC(=O)Nc1cccc(OCC(=O)N(C)C)c1CNS(C)(=O)=O
# 9          39                     CC(=O)Nc1cccc(C)c1NC(=O)CO
#
#                                            reactants  \
# 0        [('CN(C)C(=O)c1ccccc1Cl', 'O=C1C(O)CCN1C')]
# 1  [('C[Si](C)(Oc1ccccc1O)C(C)(C)C', 'O=C1C(Cl)CC...
# 2  [('Cc1cccc(O)c1OCc1ccccc1', 'O=C1C(Cl)CCN1C'),...
# 3  [('Cc1cc(O)c(OCc2ccccc2)c(C)c1', 'O=C1C(Cl)CCN...
# ...
