# %%
import pandas as pd

# %% [markdown]
# ## Plan
# Tasks:
# 1. Understand the distribution of the ddG and RMSD in general for RDKit placement.
# 2. Understand the difference between ddG and RMSD for PyRosetta vs RDKit placement.
#
# - Should run pythonically
# - Should make name with the number of repeat added to it so the folder is not overwritten

# %%
# make master csv with names to run
df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8/bases/MASTER.csv', index_col=0)
df
# Out:
#                                 smiles                         name  \
# 0    Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  LXINEYASRREWNB-UHFFFAOYSA-N
# 1    N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  BHKVBKDDVLQZCR-UHFFFAOYSA-N
# 2    N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  GHOYNZDJCPMSBM-UHFFFAOYSA-N
# 3   Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  BCPKNOZHZDDVQN-UHFFFAOYSA-N
# 4   N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  UASLKFQKYXHLQJ-UHFFFAOYSA-N
# ..                                 ...                          ...
# 65        N#CCC(=O)Nc1ccccc1(NC(=O)CO)  LISNPGIFHAQIEO-UHFFFAOYSA-N
# 66     Cc1cc(NC(=O)CO)c(NC(=O)CC#N)cc1  HZNFTESFLXXWPL-UHFFFAOYSA-N
# 67        N#CCC(=O)Nc1ccncc1(NC(=O)CO)  GCAQUNSOGCAEFO-UHFFFAOYSA-N
# 68     c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1F  VXLLSVROUGTXAB-UHFFFAOYSA-N
# 69     c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1C  YIPNWJATCFTMPP-UHFFFAOYSA-N
#
#                 frag_small                                          reactants  \
# ...

# %%
# add 10 repeats of each row, changing the name from 0 to 10
rows_to_add = []
for i, row in df.iterrows():
    for x in range(10):
        new_row = row.copy()
        new_row['name'] = f"{row['name']}-{x}"
        rows_to_add.append(new_row)
df = pd.DataFrame(rows_to_add)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                 smiles                           name  \
# 0    Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  LXINEYASRREWNB-UHFFFAOYSA-N-0
# 1    Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  LXINEYASRREWNB-UHFFFAOYSA-N-1
# 2    Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  LXINEYASRREWNB-UHFFFAOYSA-N-2
# 3    Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  LXINEYASRREWNB-UHFFFAOYSA-N-3
# 4    Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  LXINEYASRREWNB-UHFFFAOYSA-N-4
# ..                                 ...                            ...
# 685    c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1C  YIPNWJATCFTMPP-UHFFFAOYSA-N-5
# 686    c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1C  YIPNWJATCFTMPP-UHFFFAOYSA-N-6
# 687    c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1C  YIPNWJATCFTMPP-UHFFFAOYSA-N-7
# 688    c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1C  YIPNWJATCFTMPP-UHFFFAOYSA-N-8
# 689    c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1C  YIPNWJATCFTMPP-UHFFFAOYSA-N-9
#
#                  frag_small  \
# 0    ['Ax0310a', 'Ax0416a']
# 1    ['Ax0310a', 'Ax0416a']
# 2    ['Ax0310a', 'Ax0416a']
# ...

# %%
df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/repeat_placements_april22/MASTER_10_REPEATS.csv')
