# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw, inchi, rdChemReactions
from IPython.display import display, Markdown
import json
import tqdm
import warnings
from rdkit import RDLogger

# Suppress RDKit warnings
warnings.filterwarnings("ignore", category=UserWarning)
RDLogger.DisableLog('rdApp.*')  # This will suppress all RDKit-related logs

# %%
with open('/Users/kate_fieseler/PycharmProjects/syndirella/syndirella/constants/RXN_SMARTS_CONSTANTS.json') as f:
    smarts = json.load(f)

# %%
# defs
def check_products(products,
                   product_smiles,
                   reaction_id,
                   try_num):
    #print(products)
    products = [product[0] for product in products]
    if len(products) == 0 and try_num==1:
        print(reaction_id)
        raise Exception('no products')
    any_sanitized = False
    for product in products:
        try:
            Chem.SanitizeMol(product)
            any_sanitized = True
            break  # As soon as one is sanitized successfully, we can stop checking
        except:
            continue  # If an error occurs, move to the next product
    if not any_sanitized:
        print('None of the products could be sanitised.')
        return False
    # check if one matches the product_smiles by inchi key
    if any_sanitized:
        true_inchi = inchi.MolToInchiKey(Chem.MolFromSmiles(product_smiles))
        for product in products:
            if true_inchi != inchi.MolToInchiKey(product):
                print('Incorrect product')
                print(reaction_id)
                print(
                print(true_inchi)
                print(inchi.MolToInchiKey(product))
                print(Chem.MolToSmiles(product))
                return False
        #print('All correct products')
    return True

def correct_transformation(reaction_name,
                           product_smiles,
                           reactant_smiles,
                           reaction_id):
    # print('REACTION NAME:', reaction_name)
    # print('PRODUCT:', product_smiles)
    # print('REACTANTS:', reactant_smiles)
    # print('REACTION_ID:', reaction_id)
    # define reaction
    rxn_smarts = smarts[reaction_name]
    rxn = rdChemReactions.ReactionFromSmarts(rxn_smarts)
    reactants = [Chem.MolFromSmiles(smile) for smile in reactant_smiles]
    assert len(reactants) == len(reactant_smiles)
    reactants = tuple(reactants)
    products = rxn.RunReactants(reactants)
    check = check_products(products, product_smiles, reaction_id, 1, reactant_smiles)
    # if check is False:
    #     reactants = reactants[::-1] # inverse tuple
    #     products = rxn.RunReactants(reactants)
    #     check = check_products(products, product_smiles, reaction_id, 2)
    # print()
    return check

def apply_function(row):
    return correct_transformation(row['reaction_type'], row['product_smiles'], row['reactant_smiles'], row['reaction_id'])

# %%
df = pd.read_pickle('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8/may2_reactions_use.pkl.gz')
# only look at deprotections
deprotections = ["N-Boc_deprotection", "N-Bn_deprotection", "TBS_alcohol_deprotection", "Benzyl_alcohol_deprotection"]
df = df[df['reaction_type'].isin(deprotections)]
df
# Out:
#         reaction_id                reaction_type  product_id reactant_ids  \
# 1                 2           N-Boc_deprotection          88         {87}
# 4                 5           N-Boc_deprotection          93         {92}
# 7                 8           N-Boc_deprotection          97         {96}
# 10               11           N-Boc_deprotection         101        {100}
# 13               14           N-Boc_deprotection         105        {104}
# ...             ...                          ...         ...          ...
# 107773       107774  Benzyl_alcohol_deprotection      109407     {109409}
# 107930       107931  Benzyl_alcohol_deprotection      109566     {109565}
# 108103       108104  Benzyl_alcohol_deprotection      109739     {109649}
# 108109       108110  Benzyl_alcohol_deprotection      109746     {109745}
# 108128       108129  Benzyl_alcohol_deprotection      109765     {109764}
#
#                                    product_smiles  \
# 1                        Cn1ncc(N)c1NC(=O)C1CCCO1
# 4                     Cn1ncc(N)c1NC(=O)C1(C)CCCO1
# 7                    Cn1ncc(N)c1NC(=O)C1CCC(=O)O1
# 10                    CC1CCC(C(=O)Nc2c(N)cnn2C)O1
# 13                      Cn1ncc(N)c1NC(=O)C1OCCC1F
# ...                                           ...
# 107773    O=C(COc1cc(O)ccn1)N1CCOC(c2ccc(F)cc2)C1
# 107930      O=C(COc1cc(O)c2ccccc2n1)N1CCOCC1C1CC1
# 108103  CC1CN(C(=O)COc2cc(O)c3ccccc3n2)CC(C)(C)O1
# 108109     O=C(COc1cc(O)c2ccccc2n1)N1CCOC2CCCCC21
# 108128  CC1CN(C(=O)C(C)Oc2cc(O)c3ccccc3n2)CC(C)O1
#
#                                           reactant_smiles  \
# 1                {Cn1ncc(NC(=O)OC(C)(C)C)c1NC(=O)C1CCCO1}
# 4             {Cn1ncc(NC(=O)OC(C)(C)C)c1NC(=O)C1(C)CCCO1}
# 7            {Cn1ncc(NC(=O)OC(C)(C)C)c1NC(=O)C1CCC(=O)O1}
# 10            {CC1CCC(C(=O)Nc2c(NC(=O)OC(C)(C)C)cnn2C)O1}
# 13              {Cn1ncc(NC(=O)OC(C)(C)C)c1NC(=O)C1OCCC1F}
# ...                                                   ...
# 107773  {O=C(COc1cc(OCc2ccccc2)ccn1)N1CCOC(c2ccc(F)cc2...
# 107930   {O=C(COc1cc(OCc2ccccc2)c2ccccc2n1)N1CCOCC1C1CC1}
# 108103  {CC1CN(C(=O)COc2cc(OCc3ccccc3)c3ccccc3n2)CC(C)...
# 108109  {O=C(COc1cc(OCc2ccccc2)c2ccccc2n1)N1CCOC2CCCCC21}
# 108128  {CC1CN(C(=O)C(C)Oc2cc(OCc3ccccc3)c3ccccc3n2)CC...
#
#                                           product_mol  \
# 1       <rdkit.Chem.rdchem.Mol object at 0x30493b970>
# 4       <rdkit.Chem.rdchem.Mol object at 0x30493ba60>
# 7       <rdkit.Chem.rdchem.Mol object at 0x30493bb50>
# 10      <rdkit.Chem.rdchem.Mol object at 0x30493bc40>
# 13      <rdkit.Chem.rdchem.Mol object at 0x30493bd30>
# ...                                               ...
# 107773  <rdkit.Chem.rdchem.Mol object at 0x3588b4c70>
# 107930  <rdkit.Chem.rdchem.Mol object at 0x3588b7d80>
# 108103  <rdkit.Chem.rdchem.Mol object at 0x3588e33d0>
# 108109  <rdkit.Chem.rdchem.Mol object at 0x3588e35b0>
# 108128  <rdkit.Chem.rdchem.Mol object at 0x3588e3ba0>
#
#                                           reactant_mols
# 1       {<rdkit.Chem.rdchem.Mol object at 0x355618590>}
# 4       {<rdkit.Chem.rdchem.Mol object at 0x355618720>}
# 7       {<rdkit.Chem.rdchem.Mol object at 0x3556188b0>}
# 10      {<rdkit.Chem.rdchem.Mol object at 0x355618a40>}
# 13      {<rdkit.Chem.rdchem.Mol object at 0x355618bd0>}
# ...                                                 ...
# 107773  {<rdkit.Chem.rdchem.Mol object at 0x36be88040>}
# 107930  {<rdkit.Chem.rdchem.Mol object at 0x36beae250>}
# 108103  {<rdkit.Chem.rdchem.Mol object at 0x36c200ea0>}
# 108109  {<rdkit.Chem.rdchem.Mol object at 0x36c201210>}
# 108128  {<rdkit.Chem.rdchem.Mol object at 0x36c201da0>}
#
# [1774 rows x 8 columns]

# %%
df['new_smarts_check'] = [apply_function(row) for index, row in tqdm.tqdm(df.iterrows(), total=df.shape[0])]
# Out:
#  64%|██████▍   | 1141/1774 [00:00<00:00, 1212.85it/s]
# Incorrect product
# LHGGVNQTVVGQJQ-UHFFFAOYSA-N
# DPTVHVRIENHKII-UHFFFAOYSA-N
# CC(=O)Nc1cc(F)ccc1N
# Incorrect product
# LCCYFDVSWREFOO-UHFFFAOYSA-N
# KEBCEKWOAOJDJP-UHFFFAOYSA-N
# Nc1ccc(F)cc1NC(=O)CF
# Incorrect product
# NQEWJOKHXIEAKG-UHFFFAOYSA-N
# GPGUKPRERLLVMH-UHFFFAOYSA-N
# CCC(=O)Nc1cc(F)ccc1N
# Incorrect product
# BMJMMJXAZYFDQQ-UHFFFAOYSA-N
# YXNHYCJPOISHSZ-UHFFFAOYSA-N
# C=CC(=O)Nc1cc(F)ccc1N
# Incorrect product
# BSGIRRQRZAKCTP-UHFFFAOYSA-N
# VJFGCQQXKBHDEW-UHFFFAOYSA-N
# Nc1ccc(F)cc1NC(=O)CCl
# Incorrect product
# ICKRSEMNXBGKSJ-UHFFFAOYSA-N
# CNXKXLQJEOPONG-UHFFFAOYSA-N
# Nc1ccc(F)cc1NC(=O)CI
# Incorrect product
# IYTMUKDCYMGZDQ-UHFFFAOYSA-N
# FOIBPMNXVLDNPX-UHFFFAOYSA-N
# CC(=O)Nc1ccc(Cl)cc1N
# Incorrect product
# UPWILJJLIPSTTD-UHFFFAOYSA-N
# ARFYTLSTQXQJOY-UHFFFAOYSA-N
# Nc1ccc(F)cc1NC(=O)CO
# Incorrect product
# QSJDPCLGUSZRJS-UHFFFAOYSA-N
# ONCCPEDIICZPDU-UHFFFAOYSA-N
# Nc1ccc(F)cc1NC(=O)CBr
# Incorrect product
# UEVGFONSKPOCAR-UHFFFAOYSA-N
# VJGUFTRYOCAQKF-UHFFFAOYSA-N
# Nc1ccc(F)cc1NC(=O)CS
# Incorrect product
# XZHDLMQALCXQNH-UHFFFAOYSA-N
# KGVOCNXFFWCZMN-UHFFFAOYSA-N
# C#CC(=O)Nc1cc(F)ccc1N
# 100%|██████████| 1774/1774 [00:01<00:00, 1191.19it/s]
# Incorrect product
# XLTRZUXWMURUPF-UHFFFAOYSA-N
# UFHIDTWATWLAKC-UHFFFAOYSA-N
# Nc1cc(Cl)ccc1NC(=O)CO
# Incorrect product
# VROZXPDGMQCLMX-UHFFFAOYSA-N
# COMGHSIWPXYKII-UHFFFAOYSA-N
# Nc1cc(Cl)ccc1NC(=O)C1CO1
# Incorrect product
# MYDPTAQFDRHJPS-UHFFFAOYSA-N
# GYBHKSPGNUVQMA-UHFFFAOYSA-N
# Nc1cc(Cl)ccc1NC(=O)C(O)O
# Incorrect product
# HXYPUCCJPAEXII-UHFFFAOYSA-N
# HGROLCBXIKCSPH-UHFFFAOYSA-N
# Cc1ccc(N)c(NC(=O)C(C)O)c1
# Incorrect product
# QPFFXTAITBJALQ-UHFFFAOYSA-N
# TVHZLIUHDUAFLV-UHFFFAOYSA-N
# Nc1cc(F)ccc1NC(=O)C1CO1
# Incorrect product
# DHVIEWZDWPITPZ-UHFFFAOYSA-N
# VPNZFUSMVJRGDK-UHFFFAOYSA-N
# NOCC(=O)Nc1ccc(Cl)cc1N
# Incorrect product
# ZAMJZRUHWLFLCH-UHFFFAOYSA-N
# YJMBLWUQBLQPCB-UHFFFAOYSA-N
# Nc1cc(F)ccc1NC(=O)C(O)O
# Incorrect product
# CJMNCVNHJPCSTA-UHFFFAOYSA-N
# SXRQPBLERISXHQ-UHFFFAOYSA-N
# NOCC(=O)Nc1cc(F)ccc1N
# Incorrect product
# ZQTGPFVLTGUIEV-UHFFFAOYSA-N
# RNGMNICPQROFRB-UHFFFAOYSA-N
# Cc1ccc(NC(=O)CO)c(N)c1
# Incorrect product
# JEKGUCMGZHMSAI-UHFFFAOYSA-N
# BHIJUWISGIHYDX-UHFFFAOYSA-N
# CC(O)C(=O)Nc1ccc(Cl)cc1N
# Incorrect product
# AZPQJTCJBKKYMS-UHFFFAOYSA-N
# FZXJSJLMIAPWHH-UHFFFAOYSA-N
# CC(O)C(=O)Nc1cc(F)ccc1N
# Incorrect product
# UFMIERYWCQIVMG-UHFFFAOYSA-N
# DWEOSAKVUDEEQI-UHFFFAOYSA-N
# COCC(=O)Nc1ccc(F)cc1N
# Incorrect product
# YEMXABZYTNWQBB-UHFFFAOYSA-N
# URKUOJISODVABZ-UHFFFAOYSA-N
# COCC(=O)Nc1ccc(C)cc1N
# Incorrect product
# BSTSCJWJFYXMPN-UHFFFAOYSA-N
# RDIIUWCWRSYJPY-UHFFFAOYSA-N
# COc1ccc(NC(=O)CO)c(N)c1
# Incorrect product
# FXJOLIHRTGBELB-UHFFFAOYSA-N
# BNLCTXFMRKLRME-UHFFFAOYSA-N
# Cc1ccc(NC(=O)C2CO2)c(N)c1
# Incorrect product
# WZGYRWMRWZTQTC-UHFFFAOYSA-N
# UQBPTZNEBYJYQZ-UHFFFAOYSA-N
# Cc1ccc(NC(=O)CON)c(N)c1
# Incorrect product
# DUVRPKHPSCXWGC-UHFFFAOYSA-N
# ZRKLXNXLSGYRBU-UHFFFAOYSA-N
# Cc1ccc(NC(=O)C(O)O)c(N)c1

# %%
df
# Out:
#         reaction_id                reaction_type  product_id reactant_ids  \
# 1                 2           N-Boc_deprotection          88         {87}
# 4                 5           N-Boc_deprotection          93         {92}
# 7                 8           N-Boc_deprotection          97         {96}
# 10               11           N-Boc_deprotection         101        {100}
# 13               14           N-Boc_deprotection         105        {104}
# ...             ...                          ...         ...          ...
# 107773       107774  Benzyl_alcohol_deprotection      109407     {109409}
# 107930       107931  Benzyl_alcohol_deprotection      109566     {109565}
# 108103       108104  Benzyl_alcohol_deprotection      109739     {109649}
# 108109       108110  Benzyl_alcohol_deprotection      109746     {109745}
# 108128       108129  Benzyl_alcohol_deprotection      109765     {109764}
#
#                                    product_smiles  \
# 1                        Cn1ncc(N)c1NC(=O)C1CCCO1
# 4                     Cn1ncc(N)c1NC(=O)C1(C)CCCO1
# 7                    Cn1ncc(N)c1NC(=O)C1CCC(=O)O1
# 10                    CC1CCC(C(=O)Nc2c(N)cnn2C)O1
# 13                      Cn1ncc(N)c1NC(=O)C1OCCC1F
# ...                                           ...
# 107773    O=C(COc1cc(O)ccn1)N1CCOC(c2ccc(F)cc2)C1
# 107930      O=C(COc1cc(O)c2ccccc2n1)N1CCOCC1C1CC1
# 108103  CC1CN(C(=O)COc2cc(O)c3ccccc3n2)CC(C)(C)O1
# 108109     O=C(COc1cc(O)c2ccccc2n1)N1CCOC2CCCCC21
# 108128  CC1CN(C(=O)C(C)Oc2cc(O)c3ccccc3n2)CC(C)O1
#
#                                           reactant_smiles  \
# 1                {Cn1ncc(NC(=O)OC(C)(C)C)c1NC(=O)C1CCCO1}
# 4             {Cn1ncc(NC(=O)OC(C)(C)C)c1NC(=O)C1(C)CCCO1}
# 7            {Cn1ncc(NC(=O)OC(C)(C)C)c1NC(=O)C1CCC(=O)O1}
# 10            {CC1CCC(C(=O)Nc2c(NC(=O)OC(C)(C)C)cnn2C)O1}
# 13              {Cn1ncc(NC(=O)OC(C)(C)C)c1NC(=O)C1OCCC1F}
# ...                                                   ...
# 107773  {O=C(COc1cc(OCc2ccccc2)ccn1)N1CCOC(c2ccc(F)cc2...
# 107930   {O=C(COc1cc(OCc2ccccc2)c2ccccc2n1)N1CCOCC1C1CC1}
# 108103  {CC1CN(C(=O)COc2cc(OCc3ccccc3)c3ccccc3n2)CC(C)...
# 108109  {O=C(COc1cc(OCc2ccccc2)c2ccccc2n1)N1CCOC2CCCCC21}
# 108128  {CC1CN(C(=O)C(C)Oc2cc(OCc3ccccc3)c3ccccc3n2)CC...
#
#                                           product_mol  \
# 1       <rdkit.Chem.rdchem.Mol object at 0x30493b970>
# 4       <rdkit.Chem.rdchem.Mol object at 0x30493ba60>
# 7       <rdkit.Chem.rdchem.Mol object at 0x30493bb50>
# 10      <rdkit.Chem.rdchem.Mol object at 0x30493bc40>
# 13      <rdkit.Chem.rdchem.Mol object at 0x30493bd30>
# ...                                               ...
# 107773  <rdkit.Chem.rdchem.Mol object at 0x3588b4c70>
# 107930  <rdkit.Chem.rdchem.Mol object at 0x3588b7d80>
# 108103  <rdkit.Chem.rdchem.Mol object at 0x3588e33d0>
# 108109  <rdkit.Chem.rdchem.Mol object at 0x3588e35b0>
# 108128  <rdkit.Chem.rdchem.Mol object at 0x3588e3ba0>
#
#                                           reactant_mols  new_smarts_check
# 1       {<rdkit.Chem.rdchem.Mol object at 0x355618590>}              True
# 4       {<rdkit.Chem.rdchem.Mol object at 0x355618720>}              True
# 7       {<rdkit.Chem.rdchem.Mol object at 0x3556188b0>}              True
# 10      {<rdkit.Chem.rdchem.Mol object at 0x355618a40>}              True
# 13      {<rdkit.Chem.rdchem.Mol object at 0x355618bd0>}              True
# ...                                                 ...               ...
# 107773  {<rdkit.Chem.rdchem.Mol object at 0x36be88040>}              True
# 107930  {<rdkit.Chem.rdchem.Mol object at 0x36beae250>}              True
# 108103  {<rdkit.Chem.rdchem.Mol object at 0x36c200ea0>}              True
# 108109  {<rdkit.Chem.rdchem.Mol object at 0x36c201210>}              True
# 108128  {<rdkit.Chem.rdchem.Mol object at 0x36c201da0>}              True
#
# [1774 rows x 9 columns]

# %%
bad_df = df[df['new_smarts_check'] == False]
bad_df
# Out:
#         reaction_id       reaction_type  product_id reactant_ids  \
# 65983         65984  N-Boc_deprotection       67031      {67034}
# 66027         66028  N-Boc_deprotection       67078      {67080}
# 66110         66111  N-Boc_deprotection       67158      {67160}
# 66136         66137  N-Boc_deprotection       67183      {67185}
# 66151         66152  N-Boc_deprotection       67197      {67199}
# 66256         66257  N-Boc_deprotection       67301      {67303}
# 66403         66404  N-Boc_deprotection       67448      {67451}
# 66481         66482  N-Boc_deprotection       67526      {67528}
# 66498         66499  N-Boc_deprotection       67542      {67544}
# 66576         66577  N-Boc_deprotection       67620      {67622}
# 67127         67128  N-Boc_deprotection       68168      {68170}
# 102341       102342  N-Boc_deprotection      103930     {103932}
# 102377       102378  N-Boc_deprotection      103963     {103965}
# 102388       102389  N-Boc_deprotection      103973     {103975}
# 102420       102421  N-Boc_deprotection       87472     {104006}
# 102446       102447  N-Boc_deprotection      104031      {94288}
# 102451       102452  N-Boc_deprotection      104034     {104036}
# 102456       102457  N-Boc_deprotection      104039      {94291}
# 102467       102468  N-Boc_deprotection       94277     {104051}
# 102511       102512  N-Boc_deprotection      104093      {87461}
# 102536       102537  N-Boc_deprotection      104115     {104117}
# 102593       102594  N-Boc_deprotection       94320     {104173}
# 102633       102634  N-Boc_deprotection      104211      {94457}
# 102648       102649  N-Boc_deprotection      104225      {87616}
# 102777       102778  N-Boc_deprotection       77435     {104355}
# 102826       102827  N-Boc_deprotection      104402      {87478}
# 102841       102842  N-Boc_deprotection      104416      {87464}
# 102853       102854  N-Boc_deprotection      104427      {87481}
#
#                    product_smiles                            reactant_smiles  \
# 65983         CC(=O)Nc1ccc(F)cc1N        {CC(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C}
# 66027        Nc1cc(F)ccc1NC(=O)CF       {CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CF}
# 66110        CCC(=O)Nc1ccc(F)cc1N       {CCC(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C}
# 66136       C=CC(=O)Nc1ccc(F)cc1N      {C=CC(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C}
# 66151       Nc1cc(F)ccc1NC(=O)CCl      {CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CCl}
# 66256        Nc1cc(F)ccc1NC(=O)CI       {CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CI}
# 66403        CC(=O)Nc1cc(Cl)ccc1N       {CC(=O)Nc1ccc(Cl)cc1NC(=O)OC(C)(C)C}
# 66481        Nc1cc(F)ccc1NC(=O)CO       {CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CO}
# 66498       Nc1cc(F)ccc1NC(=O)CBr      {CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CBr}
# 66576        Nc1cc(F)ccc1NC(=O)CS       {CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CS}
# 67127       C#CC(=O)Nc1ccc(F)cc1N      {C#CC(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C}
# 102341      Nc1ccc(Cl)cc1NC(=O)CO      {CC(C)(C)OC(=O)Nc1cc(Cl)ccc1NC(=O)CO}
# 102377   Nc1ccc(Cl)cc1NC(=O)C1CO1   {CC(C)(C)OC(=O)Nc1cc(Cl)ccc1NC(=O)C1CO1}
# 102388   Nc1ccc(Cl)cc1NC(=O)C(O)O   {CC(C)(C)OC(=O)Nc1cc(Cl)ccc1NC(=O)C(O)O}
# 102420  Cc1ccc(NC(=O)C(C)O)c(N)c1  {Cc1ccc(NC(=O)OC(C)(C)C)c(NC(=O)C(C)O)c1}
# 102446    Nc1ccc(F)cc1NC(=O)C1CO1    {CC(C)(C)OC(=O)Nc1cc(F)ccc1NC(=O)C1CO1}
# 102451     NOCC(=O)Nc1cc(Cl)ccc1N     {CC(C)(C)OC(=O)Nc1cc(Cl)ccc1NC(=O)CON}
# 102456    Nc1ccc(F)cc1NC(=O)C(O)O    {CC(C)(C)OC(=O)Nc1cc(F)ccc1NC(=O)C(O)O}
# 102467      NOCC(=O)Nc1ccc(F)cc1N      {CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CON}
# 102511     Cc1ccc(N)c(NC(=O)CO)c1     {Cc1ccc(NC(=O)CO)c(NC(=O)OC(C)(C)C)c1}
# 102536   CC(O)C(=O)Nc1cc(Cl)ccc1N   {CC(O)C(=O)Nc1ccc(Cl)cc1NC(=O)OC(C)(C)C}
# 102593    CC(O)C(=O)Nc1ccc(F)cc1N    {CC(O)C(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C}
# 102633      COCC(=O)Nc1cc(F)ccc1N      {COCC(=O)Nc1ccc(F)cc1NC(=O)OC(C)(C)C}
# 102648      COCC(=O)Nc1cc(C)ccc1N      {COCC(=O)Nc1ccc(C)cc1NC(=O)OC(C)(C)C}
# 102777    COc1ccc(N)c(NC(=O)CO)c1    {COc1ccc(NC(=O)CO)c(NC(=O)OC(C)(C)C)c1}
# 102826  Cc1ccc(N)c(NC(=O)C2CO2)c1  {Cc1ccc(NC(=O)C2CO2)c(NC(=O)OC(C)(C)C)c1}
# 102841    Cc1ccc(N)c(NC(=O)CON)c1    {Cc1ccc(NC(=O)CON)c(NC(=O)OC(C)(C)C)c1}
# 102853  Cc1ccc(N)c(NC(=O)C(O)O)c1  {Cc1ccc(NC(=O)C(O)O)c(NC(=O)OC(C)(C)C)c1}
#
#                                           product_mol  \
# 65983   <rdkit.Chem.rdchem.Mol object at 0x36d7cd620>
# 66027   <rdkit.Chem.rdchem.Mol object at 0x36d7ce3e0>
# 66110   <rdkit.Chem.rdchem.Mol object at 0x36d7cfdd0>
# 66136   <rdkit.Chem.rdchem.Mol object at 0x35aae0630>
# 66151   <rdkit.Chem.rdchem.Mol object at 0x35aae0ae0>
# 66256   <rdkit.Chem.rdchem.Mol object at 0x35aae2bb0>
# 66403   <rdkit.Chem.rdchem.Mol object at 0x35aaf99e0>
# 66481   <rdkit.Chem.rdchem.Mol object at 0x35aafb240>
# 66498   <rdkit.Chem.rdchem.Mol object at 0x35aafb790>
# 66576   <rdkit.Chem.rdchem.Mol object at 0x35aa65030>
# 67127   <rdkit.Chem.rdchem.Mol object at 0x35aa1fce0>
# 102341  <rdkit.Chem.rdchem.Mol object at 0x36e632430>
# 102377  <rdkit.Chem.rdchem.Mol object at 0x36e632f70>
# 102388  <rdkit.Chem.rdchem.Mol object at 0x36e6332e0>
# 102420  <rdkit.Chem.rdchem.Mol object at 0x36e633ce0>
# 102446  <rdkit.Chem.rdchem.Mol object at 0x36e680540>
# 102451  <rdkit.Chem.rdchem.Mol object at 0x36e6806d0>
# 102456  <rdkit.Chem.rdchem.Mol object at 0x36e680860>
# 102467  <rdkit.Chem.rdchem.Mol object at 0x36e680bd0>
# 102511  <rdkit.Chem.rdchem.Mol object at 0x36e681990>
# 102536  <rdkit.Chem.rdchem.Mol object at 0x36e682160>
# 102593  <rdkit.Chem.rdchem.Mol object at 0x36e683330>
# 102633  <rdkit.Chem.rdchem.Mol object at 0x36e683fb0>
# 102648  <rdkit.Chem.rdchem.Mol object at 0x36e6bc4a0>
# 102777  <rdkit.Chem.rdchem.Mol object at 0x36e6becf0>
# 102826  <rdkit.Chem.rdchem.Mol object at 0x36e6bfc40>
# 102841  <rdkit.Chem.rdchem.Mol object at 0x36e6f8130>
# 102853  <rdkit.Chem.rdchem.Mol object at 0x36e6f84f0>
#
#                                           reactant_mols  new_smarts_check
# 65983   {<rdkit.Chem.rdchem.Mol object at 0x35f089ee0>}             False
# 66027   {<rdkit.Chem.rdchem.Mol object at 0x35f08b6f0>}             False
# 66110   {<rdkit.Chem.rdchem.Mol object at 0x35f0a25c0>}             False
# 66136   {<rdkit.Chem.rdchem.Mol object at 0x35f0a3420>}             False
# 66151   {<rdkit.Chem.rdchem.Mol object at 0x35f0a3c40>}             False
# 66256   {<rdkit.Chem.rdchem.Mol object at 0x35f0c7a60>}             False
# 66403   {<rdkit.Chem.rdchem.Mol object at 0x35f205300>}             False
# 66481   {<rdkit.Chem.rdchem.Mol object at 0x35f230220>}             False
# 66498   {<rdkit.Chem.rdchem.Mol object at 0x35f230c20>}             False
# 66576   {<rdkit.Chem.rdchem.Mol object at 0x35f233ba0>}             False
# 67127   {<rdkit.Chem.rdchem.Mol object at 0x35f2f1170>}             False
# 102341  {<rdkit.Chem.rdchem.Mol object at 0x36a024ef0>}             False
# 102377  {<rdkit.Chem.rdchem.Mol object at 0x36a026250>}             False
# 102388  {<rdkit.Chem.rdchem.Mol object at 0x36a0267f0>}             False
# 102420  {<rdkit.Chem.rdchem.Mol object at 0x36a0278d0>}             False
# 102446  {<rdkit.Chem.rdchem.Mol object at 0x36a050680>}             False
# 102451  {<rdkit.Chem.rdchem.Mol object at 0x36a050900>}             False
# 102456  {<rdkit.Chem.rdchem.Mol object at 0x36a050b80>}             False
# 102467  {<rdkit.Chem.rdchem.Mol object at 0x36a0511c0>}             False
# 102511  {<rdkit.Chem.rdchem.Mol object at 0x36a052c00>}             False
# 102536  {<rdkit.Chem.rdchem.Mol object at 0x36a053ab0>}             False
# 102593  {<rdkit.Chem.rdchem.Mol object at 0x36a075c10>}             False
# 102633  {<rdkit.Chem.rdchem.Mol object at 0x36a0773d0>}             False
# 102648  {<rdkit.Chem.rdchem.Mol object at 0x36a077c90>}             False
# 102777  {<rdkit.Chem.rdchem.Mol object at 0x36a0b4b30>}             False
# 102826  {<rdkit.Chem.rdchem.Mol object at 0x36a0b68e0>}             False
# 102841  {<rdkit.Chem.rdchem.Mol object at 0x36a0b71a0>}             False
# 102853  {<rdkit.Chem.rdchem.Mol object at 0x36a0b7880>}             False

# %%
bad_df['unpacked_reactants'] = df['reactant_smiles'].apply(lambda x: x.pop())
bad_df
# Out:
# /var/folders/sg/gb03t0zx5sz8vw2lxlghz1gr0000gn/T/ipykernel_2237/185269378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_df['unpacked_reactants'] = df['reactant_smiles'].apply(lambda x: x.pop())
#         reaction_id       reaction_type  product_id reactant_ids  \
# 65983         65984  N-Boc_deprotection       67031      {67034}
# 66027         66028  N-Boc_deprotection       67078      {67080}
# 66110         66111  N-Boc_deprotection       67158      {67160}
# 66136         66137  N-Boc_deprotection       67183      {67185}
# 66151         66152  N-Boc_deprotection       67197      {67199}
# 66256         66257  N-Boc_deprotection       67301      {67303}
# 66403         66404  N-Boc_deprotection       67448      {67451}
# 66481         66482  N-Boc_deprotection       67526      {67528}
# 66498         66499  N-Boc_deprotection       67542      {67544}
# 66576         66577  N-Boc_deprotection       67620      {67622}
# 67127         67128  N-Boc_deprotection       68168      {68170}
# 102341       102342  N-Boc_deprotection      103930     {103932}
# 102377       102378  N-Boc_deprotection      103963     {103965}
# 102388       102389  N-Boc_deprotection      103973     {103975}
# 102420       102421  N-Boc_deprotection       87472     {104006}
# 102446       102447  N-Boc_deprotection      104031      {94288}
# 102451       102452  N-Boc_deprotection      104034     {104036}
# 102456       102457  N-Boc_deprotection      104039      {94291}
# 102467       102468  N-Boc_deprotection       94277     {104051}
# 102511       102512  N-Boc_deprotection      104093      {87461}
# 102536       102537  N-Boc_deprotection      104115     {104117}
# 102593       102594  N-Boc_deprotection       94320     {104173}
# 102633       102634  N-Boc_deprotection      104211      {94457}
# 102648       102649  N-Boc_deprotection      104225      {87616}
# 102777       102778  N-Boc_deprotection       77435     {104355}
# 102826       102827  N-Boc_deprotection      104402      {87478}
# 102841       102842  N-Boc_deprotection      104416      {87464}
# 102853       102854  N-Boc_deprotection      104427      {87481}
#
#                    product_smiles reactant_smiles  \
# 65983         CC(=O)Nc1ccc(F)cc1N              {}
# 66027        Nc1cc(F)ccc1NC(=O)CF              {}
# 66110        CCC(=O)Nc1ccc(F)cc1N              {}
# 66136       C=CC(=O)Nc1ccc(F)cc1N              {}
# 66151       Nc1cc(F)ccc1NC(=O)CCl              {}
# 66256        Nc1cc(F)ccc1NC(=O)CI              {}
# 66403        CC(=O)Nc1cc(Cl)ccc1N              {}
# 66481        Nc1cc(F)ccc1NC(=O)CO              {}
# 66498       Nc1cc(F)ccc1NC(=O)CBr              {}
# 66576        Nc1cc(F)ccc1NC(=O)CS              {}
# 67127       C#CC(=O)Nc1ccc(F)cc1N              {}
# 102341      Nc1ccc(Cl)cc1NC(=O)CO              {}
# 102377   Nc1ccc(Cl)cc1NC(=O)C1CO1              {}
# 102388   Nc1ccc(Cl)cc1NC(=O)C(O)O              {}
# 102420  Cc1ccc(NC(=O)C(C)O)c(N)c1              {}
# 102446    Nc1ccc(F)cc1NC(=O)C1CO1              {}
# 102451     NOCC(=O)Nc1cc(Cl)ccc1N              {}
# 102456    Nc1ccc(F)cc1NC(=O)C(O)O              {}
# 102467      NOCC(=O)Nc1ccc(F)cc1N              {}
# 102511     Cc1ccc(N)c(NC(=O)CO)c1              {}
# 102536   CC(O)C(=O)Nc1cc(Cl)ccc1N              {}
# 102593    CC(O)C(=O)Nc1ccc(F)cc1N              {}
# 102633      COCC(=O)Nc1cc(F)ccc1N              {}
# 102648      COCC(=O)Nc1cc(C)ccc1N              {}
# 102777    COc1ccc(N)c(NC(=O)CO)c1              {}
# 102826  Cc1ccc(N)c(NC(=O)C2CO2)c1              {}
# 102841    Cc1ccc(N)c(NC(=O)CON)c1              {}
# 102853  Cc1ccc(N)c(NC(=O)C(O)O)c1              {}
#
#                                           product_mol  \
# 65983   <rdkit.Chem.rdchem.Mol object at 0x36d7cd620>
# 66027   <rdkit.Chem.rdchem.Mol object at 0x36d7ce3e0>
# 66110   <rdkit.Chem.rdchem.Mol object at 0x36d7cfdd0>
# 66136   <rdkit.Chem.rdchem.Mol object at 0x35aae0630>
# 66151   <rdkit.Chem.rdchem.Mol object at 0x35aae0ae0>
# 66256   <rdkit.Chem.rdchem.Mol object at 0x35aae2bb0>
# 66403   <rdkit.Chem.rdchem.Mol object at 0x35aaf99e0>
# 66481   <rdkit.Chem.rdchem.Mol object at 0x35aafb240>
# 66498   <rdkit.Chem.rdchem.Mol object at 0x35aafb790>
# 66576   <rdkit.Chem.rdchem.Mol object at 0x35aa65030>
# 67127   <rdkit.Chem.rdchem.Mol object at 0x35aa1fce0>
# 102341  <rdkit.Chem.rdchem.Mol object at 0x36e632430>
# 102377  <rdkit.Chem.rdchem.Mol object at 0x36e632f70>
# 102388  <rdkit.Chem.rdchem.Mol object at 0x36e6332e0>
# 102420  <rdkit.Chem.rdchem.Mol object at 0x36e633ce0>
# 102446  <rdkit.Chem.rdchem.Mol object at 0x36e680540>
# 102451  <rdkit.Chem.rdchem.Mol object at 0x36e6806d0>
# 102456  <rdkit.Chem.rdchem.Mol object at 0x36e680860>
# 102467  <rdkit.Chem.rdchem.Mol object at 0x36e680bd0>
# 102511  <rdkit.Chem.rdchem.Mol object at 0x36e681990>
# 102536  <rdkit.Chem.rdchem.Mol object at 0x36e682160>
# 102593  <rdkit.Chem.rdchem.Mol object at 0x36e683330>
# 102633  <rdkit.Chem.rdchem.Mol object at 0x36e683fb0>
# 102648  <rdkit.Chem.rdchem.Mol object at 0x36e6bc4a0>
# 102777  <rdkit.Chem.rdchem.Mol object at 0x36e6becf0>
# 102826  <rdkit.Chem.rdchem.Mol object at 0x36e6bfc40>
# 102841  <rdkit.Chem.rdchem.Mol object at 0x36e6f8130>
# 102853  <rdkit.Chem.rdchem.Mol object at 0x36e6f84f0>
#
#                                           reactant_mols  new_smarts_check  \
# 65983   {<rdkit.Chem.rdchem.Mol object at 0x35f089ee0>}             False
# 66027   {<rdkit.Chem.rdchem.Mol object at 0x35f08b6f0>}             False
# 66110   {<rdkit.Chem.rdchem.Mol object at 0x35f0a25c0>}             False
# 66136   {<rdkit.Chem.rdchem.Mol object at 0x35f0a3420>}             False
# 66151   {<rdkit.Chem.rdchem.Mol object at 0x35f0a3c40>}             False
# 66256   {<rdkit.Chem.rdchem.Mol object at 0x35f0c7a60>}             False
# 66403   {<rdkit.Chem.rdchem.Mol object at 0x35f205300>}             False
# 66481   {<rdkit.Chem.rdchem.Mol object at 0x35f230220>}             False
# 66498   {<rdkit.Chem.rdchem.Mol object at 0x35f230c20>}             False
# 66576   {<rdkit.Chem.rdchem.Mol object at 0x35f233ba0>}             False
# 67127   {<rdkit.Chem.rdchem.Mol object at 0x35f2f1170>}             False
# 102341  {<rdkit.Chem.rdchem.Mol object at 0x36a024ef0>}             False
# 102377  {<rdkit.Chem.rdchem.Mol object at 0x36a026250>}             False
# 102388  {<rdkit.Chem.rdchem.Mol object at 0x36a0267f0>}             False
# 102420  {<rdkit.Chem.rdchem.Mol object at 0x36a0278d0>}             False
# 102446  {<rdkit.Chem.rdchem.Mol object at 0x36a050680>}             False
# 102451  {<rdkit.Chem.rdchem.Mol object at 0x36a050900>}             False
# 102456  {<rdkit.Chem.rdchem.Mol object at 0x36a050b80>}             False
# 102467  {<rdkit.Chem.rdchem.Mol object at 0x36a0511c0>}             False
# 102511  {<rdkit.Chem.rdchem.Mol object at 0x36a052c00>}             False
# 102536  {<rdkit.Chem.rdchem.Mol object at 0x36a053ab0>}             False
# 102593  {<rdkit.Chem.rdchem.Mol object at 0x36a075c10>}             False
# 102633  {<rdkit.Chem.rdchem.Mol object at 0x36a0773d0>}             False
# 102648  {<rdkit.Chem.rdchem.Mol object at 0x36a077c90>}             False
# 102777  {<rdkit.Chem.rdchem.Mol object at 0x36a0b4b30>}             False
# 102826  {<rdkit.Chem.rdchem.Mol object at 0x36a0b68e0>}             False
# 102841  {<rdkit.Chem.rdchem.Mol object at 0x36a0b71a0>}             False
# 102853  {<rdkit.Chem.rdchem.Mol object at 0x36a0b7880>}             False
#
#                              unpacked_reactants
# 65983         CC(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C
# 66027        CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CF
# 66110        CCC(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C
# 66136       C=CC(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C
# 66151       CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CCl
# 66256        CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CI
# 66403        CC(=O)Nc1ccc(Cl)cc1NC(=O)OC(C)(C)C
# 66481        CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CO
# 66498       CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CBr
# 66576        CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CS
# 67127       C#CC(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C
# 102341      CC(C)(C)OC(=O)Nc1cc(Cl)ccc1NC(=O)CO
# 102377   CC(C)(C)OC(=O)Nc1cc(Cl)ccc1NC(=O)C1CO1
# 102388   CC(C)(C)OC(=O)Nc1cc(Cl)ccc1NC(=O)C(O)O
# 102420  Cc1ccc(NC(=O)OC(C)(C)C)c(NC(=O)C(C)O)c1
# 102446    CC(C)(C)OC(=O)Nc1cc(F)ccc1NC(=O)C1CO1
# 102451     CC(C)(C)OC(=O)Nc1cc(Cl)ccc1NC(=O)CON
# 102456    CC(C)(C)OC(=O)Nc1cc(F)ccc1NC(=O)C(O)O
# 102467      CC(C)(C)OC(=O)Nc1ccc(F)cc1NC(=O)CON
# 102511     Cc1ccc(NC(=O)CO)c(NC(=O)OC(C)(C)C)c1
# 102536   CC(O)C(=O)Nc1ccc(Cl)cc1NC(=O)OC(C)(C)C
# 102593    CC(O)C(=O)Nc1cc(F)ccc1NC(=O)OC(C)(C)C
# 102633      COCC(=O)Nc1ccc(F)cc1NC(=O)OC(C)(C)C
# 102648      COCC(=O)Nc1ccc(C)cc1NC(=O)OC(C)(C)C
# 102777    COc1ccc(NC(=O)CO)c(NC(=O)OC(C)(C)C)c1
# 102826  Cc1ccc(NC(=O)C2CO2)c(NC(=O)OC(C)(C)C)c1
# 102841    Cc1ccc(NC(=O)CON)c(NC(=O)OC(C)(C)C)c1
# 102853  Cc1ccc(NC(=O)C(O)O)c(NC(=O)OC(C)(C)C)c1

# %%
bad_df.to_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8/failed_smarts.csv')
