# %%
import pandas as pd
import os
os.chdir('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8/to_jenna/raw')
from rdkit import Chem
from rdkit.Chem import inchi

# %%
# cd A71EV2A_run4
# find . -mindepth 2 -maxdepth 2 -type f -name '*placements.csv' -exec wc -l {} +

# %%
# folders to read ~50K 
# LXINEYASRREWNB-UHFFFAOYSA-N
# BHKVBKDDVLQZCR-UHFFFAOYSA-N
# GHOYNZDJCPMSBM-UHFFFAOYSA-N
# BCPKNOZHZDDVQN-UHFFFAOYSA-N
# UASLKFQKYXHLQJ-UHFFFAOYSA-N

# %%
# huge one to look at
# YXOSKKANWJIJOY-UHFFFAOYSA-N

# %%
df1 = pd.read_pickle('BCPKNOZHZDDVQN-UHFFFAOYSA-N_3LdJjd_to_hippo.pkl.gz')
df1
# Out:
#                     base_compound_smiles 1_reaction             1_r1_smiles  \
# 0     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation           O=C(O)C1CCCO1
# 1     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation           O=C(O)C1CCCO1
# 2     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation      O=C(O)C12CC(CO1)C2
# 3     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation          O=C(O)C1OCCC1F
# 4     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation          O=C(O)C1OCCC1F
# ...                                  ...        ...                     ...
# 9995  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9996  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9997  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9998  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9999  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
#
# ...

# %%
df1.drop_duplicates(subset=['3_product_name'], keep='first', inplace=True)
df1
# Out:
#                     base_compound_smiles 1_reaction             1_r1_smiles  \
# 0     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation           O=C(O)C1CCCO1
# 1     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation           O=C(O)C1CCCO1
# 2     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation      O=C(O)C12CC(CO1)C2
# 3     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation          O=C(O)C1OCCC1F
# 4     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation          O=C(O)C1OCCC1F
# ...                                  ...        ...                     ...
# 9995  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9996  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9997  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9998  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9999  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
#
# ...

# %%
df2 = pd.read_pickle('BHKVBKDDVLQZCR-UHFFFAOYSA-N_3ADBvA_to_hippo.pkl.gz')
df2
# Out:
#                     base_compound_smiles 1_reaction       1_r1_smiles  \
# 0      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 1      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 2      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 3      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# 4      N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation     O=C(O)C1CCCO1
# ...                                  ...        ...               ...
# 13040  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  CC1CCC(C(=O)O)O1
# 13041  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  CC1CCC(C(=O)O)O1
# 13042  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  CC1CCC(C(=O)O)O1
# 13043  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  CC1CCC(C(=O)O)O1
# 13044  N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  CC1CCC(C(=O)O)O1
#
#                          1_r2_smiles 1_r_previous_product  \
# 0         CC(C)(C)OC(=O)Nc1cccc(N)c1                 None
# ...

# %%
df3 = pd.read_pickle('GHOYNZDJCPMSBM-UHFFFAOYSA-N_4NaSrt_to_hippo.pkl.gz')
df3
# Out:
#                    base_compound_smiles 1_reaction    1_r1_smiles  \
# 0     N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 1     N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 2     N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 3     N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 4     N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# ...                                 ...        ...            ...
# 9995  N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 9996  N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 9997  N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 9998  N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 9999  N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
#
#                       1_r2_smiles 1_r_previous_product  \
# 0      CC(C)(C)OC(=O)Nc1ccnc(N)c1                 None
# 1      CC(C)(C)OC(=O)Nc1ccnc(N)c1                 None
# ...

# %%
df4 = pd.read_pickle('LXINEYASRREWNB-UHFFFAOYSA-N_oq22mH_to_hippo.pkl.gz')
df4
# Out:
#                    base_compound_smiles 1_reaction             1_r1_smiles  \
# 0     Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation           O=C(O)C1CCCO1
# 1     Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation           O=C(O)C1CCCO1
# 2     Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation        CC1(C(=O)O)CCCO1
# 3     Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation        CC1(C(=O)O)CCCO1
# 4     Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation       O=C1CCC(C(=O)O)O1
# ...                                 ...        ...                     ...
# 9995  Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation  CCC12COC(C(=O)O)(C1)C2
# 9996  Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation       CCC1(C(=O)O)CCCO1
# 9997  Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation       CCC1(C(=O)O)CCCO1
# 9998  Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation       CCC1(C(=O)O)CCCO1
# 9999  Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation       CCC1(C(=O)O)CCCO1
#
#                      1_r2_smiles 1_r_previous_product  \
# ...

# %%
df5 = pd.read_pickle('UASLKFQKYXHLQJ-UHFFFAOYSA-N_Kct9up_to_hippo.pkl.gz')
df5
# Out:
#                     base_compound_smiles 1_reaction            1_r1_smiles  \
# 0     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation          O=C(O)C1CCCO1
# 1     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation          O=C(O)C1CCCO1
# 2     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation       CC1COC(C(=O)O)C1
# 3     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation       CC1COC(C(=O)O)C1
# 4     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation       CC1COC(C(=O)O)C1
# ...                                  ...        ...                    ...
# 9995  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation    O=C(O)C1CC2(CC2)CO1
# 9996  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation  O=C(O)C12CC(F)(CO1)C2
# 9997  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation  O=C(O)C12CC(F)(CO1)C2
# 9998  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation  O=C(O)C12CC(F)(CO1)C2
# 9999  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation  O=C(O)C12CC(F)(CO1)C2
#
#                          1_r2_smiles 1_r_previous_product  \
# ...

# %%
# change all values in intra_geometry_pass to False if path_to_mol is None
# change all NaN values to None
dfs = [df1, df2, df3, df4, df5]
for df in dfs:
    df['intra_geometry_pass'] = df.apply(lambda x: False if x['path_to_mol'] is None else x['intra_geometry_pass'], axis=1)
    df = df.where(pd.notnull(df), None)

# %%
df1
# Out:
#                     base_compound_smiles 1_reaction             1_r1_smiles  \
# 0     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation           O=C(O)C1CCCO1
# 1     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation           O=C(O)C1CCCO1
# 2     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation      O=C(O)C12CC(CO1)C2
# 3     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation          O=C(O)C1OCCC1F
# 4     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation          O=C(O)C1OCCC1F
# ...                                  ...        ...                     ...
# 9995  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9996  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9997  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9998  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9999  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
#
# ...

# %%
df5
# Out:
#                     base_compound_smiles 1_reaction            1_r1_smiles  \
# 0     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation          O=C(O)C1CCCO1
# 1     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation          O=C(O)C1CCCO1
# 2     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation       CC1COC(C(=O)O)C1
# 3     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation       CC1COC(C(=O)O)C1
# 4     N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation       CC1COC(C(=O)O)C1
# ...                                  ...        ...                    ...
# 9995  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation    O=C(O)C1CC2(CC2)CO1
# 9996  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation  O=C(O)C12CC(F)(CO1)C2
# 9997  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation  O=C(O)C12CC(F)(CO1)C2
# 9998  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation  O=C(O)C12CC(F)(CO1)C2
# 9999  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation  O=C(O)C12CC(F)(CO1)C2
#
#                          1_r2_smiles 1_r_previous_product  \
# ...

# %%
# save all dfs
df1.to_pickle('../send/BCPKNOZHZDDVQN-UHFFFAOYSA-N_3LdJjd_to_hippo.pkl.gz')
df2.to_pickle('../send/BHKVBKDDVLQZCR-UHFFFAOYSA-N_3ADBvA_to_hippo.pkl.gz')
df3.to_pickle('../send/GHOYNZDJCPMSBM-UHFFFAOYSA-N_4NaSrt_to_hippo.pkl.gz')
df4.to_pickle('../send/LXINEYASRREWNB-UHFFFAOYSA-N_oq22mH_to_hippo.pkl.gz')
df5.to_pickle('../send/UASLKFQKYXHLQJ-UHFFFAOYSA-N_Kct9up_to_hippo.pkl.gz')

# %%
# read in example
df = pd.read_pickle('../send/BCPKNOZHZDDVQN-UHFFFAOYSA-N_3LdJjd_to_hippo.pkl.gz')
df
# Out:
#                     base_compound_smiles 1_reaction             1_r1_smiles  \
# 0     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation           O=C(O)C1CCCO1
# 1     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation           O=C(O)C1CCCO1
# 2     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation      O=C(O)C12CC(CO1)C2
# 3     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation          O=C(O)C1OCCC1F
# 4     Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation          O=C(O)C1OCCC1F
# ...                                  ...        ...                     ...
# 9995  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9996  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9997  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9998  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
# 9999  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C12CCC(F)(CO1)C2
#
# ...

# %%
mol = Chem.MolFromSmiles(df.at[9,'base_compound_smiles'])
mol

# %%
inchi_key = inchi.MolToInchiKey(mol)
inchi_key
# Out:
# 'BCPKNOZHZDDVQN-UHFFFAOYSA-N'
