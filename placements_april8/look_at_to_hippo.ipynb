# %%
import pandas as pd
import os
os.chdir('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8')

# %%
df = pd.read_pickle('to_hippo_ex/ZMNSQVIBTKNQGL-UHFFFAOYSA-N_4JJ6rv_to_hippo.pkl.gz')
df
# Out:
#                  base_compound_smiles 1_reaction           1_r1_smiles  \
# 0    CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation               CC(=O)O
# 1    CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation         CC(=O)O.[Ag+]
# 2    CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation         CC(=O)O.[Li+]
# 3    CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation          CC(=O)O.[H+]
# 4    CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation             CC(=O)O.N
# ..                                ...        ...                   ...
# 581  CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation        C=CCOCCCC(=O)O
# 582  CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation  CC(=O)NC(C)(C)C(=O)O
# 583  CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation     O=C(O)C1CCC12CCC2
# 584  CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation     O=C(O)C1CCC12CCC2
# 585  CC(=O)Nc1cncc(OCC(=O)N2CCOCC2)c1  Amidation     O=C(O)C1CCC(O)CC1
#
#       1_r2_smiles 1_r_previous_product                 1_product_smiles  \
# ...

# %%
df = pd.read_pickle('to_hippo_ex/ZMNSQVIBTKNQGL-UHFFFAOYSA-N_Williamson_ether_synthesis_products_2of2.pkl.gz')
df
# Out:
#             r1_smiles                                         r1_mol  \
# 0    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
# 1    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
# 2    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
# 3    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
# 4    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
# ..                ...                                            ...
# 567  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
# 568  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
# 569  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
# 570  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
# 571  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12ba991d0>
#
#      r1_Williamson_ether_synthesis_num_matches  r1_lead_time  \
# 0                                            1             0
# ...

# %%
df = pd.read_pickle('to_hippo_ex/ZMNSQVIBTKNQGL-UHFFFAOYSA-N_Williamson_ether_synthesis_products_2of2_placements.pkl.gz')
df
# Out:
#             r1_smiles                                         r1_mol  \
# 0    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
# 1    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
# 2    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
# 3    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
# 4    O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
# ..                ...                                            ...
# 567  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
# 568  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
# 569  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
# 570  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
# 571  O=C(CCl)N1CCOCC1  <rdkit.Chem.rdchem.Mol object at 0x12d39c2c0>
#
#      r1_Williamson_ether_synthesis_num_matches  r1_lead_time  \
# 0                                            1             0
# ...

# %%
intra_geometry_pass = df['intra_geometry_pass'].tolist()

# %%
intra_geometry_pass
# Out:
# [False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
# ...

# %%
type(intra_geometry_pass[0])
# Out:
# bool

# %%
/data/xchem-fragalysis/kfieseler/A71EV2A_run4//ZMNSQVIBTKNQGL-UHFFFAOYSA-N/output/ZMNSQVIBTKNQGL-UHFFFAOYSA-N-4JJ6rv-base-A/ZMNSQVIBTKNQGL-UHFFFAOYSA-N-4JJ6rv-base-A.minimised.mol
