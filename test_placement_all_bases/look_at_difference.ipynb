# %%
import pandas as pd

# %%
frag = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/test_placement_all_bases/iris_fragalysis_template/iris_fragalysis_placements.csv', index_col=0)
frag
# Out:
#                                  smiles                         name  \
# 0     Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  LXINEYASRREWNB-UHFFFAOYSA-N
# 1     N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  BHKVBKDDVLQZCR-UHFFFAOYSA-N
# 2    Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  CEQDLNCRDRYDKS-UHFFFAOYSA-N
# 3     N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  GHOYNZDJCPMSBM-UHFFFAOYSA-N
# 4    Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  BCPKNOZHZDDVQN-UHFFFAOYSA-N
# ..                                  ...                          ...
# 135        N#CCC(=O)Nc1ccncc1(NC(=O)CO)  GCAQUNSOGCAEFO-UHFFFAOYSA-N
# 136       Cc1cccc(NC(=O)CO)c1NC(=O)CC#N  XBMUEFOOXYBEDQ-UHFFFAOYSA-N
# 137       N#CCC(=O)Nc1c(NC(=O)CO)cccc1F  YREOFFMAGZFGRV-UHFFFAOYSA-N
# 138     c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1F  VXLLSVROUGTXAB-UHFFFAOYSA-N
# 139     c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1F  VXLLSVROUGTXAB-UHFFFAOYSA-N
#
#                                            binary_hits  \
# 0    [b'\xef\xbe\xad\xde\x00\x00\x00\x00\r\x00\x00\...
# ...

# %%
frag['outcome'].value_counts()
# Out:
# outcome
# too moved        63
# acceptable       30
# too distant      22
# too contorted    15
# crashed          10
# Name: count, dtype: int64

# %%
frag['∆∆G'].hist()
# Out:
# <Axes: >

# %%
relax = pd.read_csv('/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/test_placement_all_bases/iris_relaxed_template/iris_relaxed_placements.csv', index_col=0)
relax
# Out:
#                                  smiles                         name  \
# 0     Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  LXINEYASRREWNB-UHFFFAOYSA-N
# 1     N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  BHKVBKDDVLQZCR-UHFFFAOYSA-N
# 2    Cc1ccc(NC(=O)CC#N)cc1NC(=O)C1CCCO1  CEQDLNCRDRYDKS-UHFFFAOYSA-N
# 3     N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  GHOYNZDJCPMSBM-UHFFFAOYSA-N
# 4    Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  BCPKNOZHZDDVQN-UHFFFAOYSA-N
# ..                                  ...                          ...
# 135        N#CCC(=O)Nc1ccncc1(NC(=O)CO)  GCAQUNSOGCAEFO-UHFFFAOYSA-N
# 136       Cc1cccc(NC(=O)CO)c1NC(=O)CC#N  XBMUEFOOXYBEDQ-UHFFFAOYSA-N
# 137       N#CCC(=O)Nc1c(NC(=O)CO)cccc1F  YREOFFMAGZFGRV-UHFFFAOYSA-N
# 138     c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1F  VXLLSVROUGTXAB-UHFFFAOYSA-N
# 139     c1cc(NC(=O)CO)c(NC(=O)CC#N)cc1F  VXLLSVROUGTXAB-UHFFFAOYSA-N
#
#                                            binary_hits  \
# 0    [b'\xef\xbe\xad\xde\x00\x00\x00\x00\r\x00\x00\...
# ...

# %%
relax['outcome'].value_counts()
# Out:
# outcome
# too moved      107
# too distant     22
# crashed         11
# Name: count, dtype: int64

# %%
relax['∆∆G'].hist()
# Out:
# <Axes: >
